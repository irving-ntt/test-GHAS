# %%
# %run "./startup"

# %%
# 📌 Definir y validar parámetros de entrada
# Se definen los parámetros requeridos para el proceso
# Crear la instancia con los parámetros esperados
params = WidgetParams({

    "sr_folio": str,
})

# Validar widgets
params.validate()
conf = ConfManager()
query = QueryManager()
db = DBXConnectionManager()

# %%
# INFONAVIT
db.drop_delta(f"DELTA_102_MARCA_43BIS_{params.sr_folio}")
db.drop_delta(f"DELTA_111_TRAMITE_{params.sr_folio}")
db.drop_delta(f"DELTA_200_BUC_354_{params.sr_folio}")
db.drop_delta(f"DELTA_200_BUC_DATOS_{params.sr_folio}")
db.drop_delta(f"DELTA_200_BUC_TRA_{params.sr_folio}")
db.drop_delta(f"DELTA_200_DPSJL_{params.sr_folio}")
db.drop_delta(f"DELTA_300_DPSJL_{params.sr_folio}")
db.drop_delta(f"DELTA_300_TRANSFERENCIA_{params.sr_folio}")
db.drop_delta(f"DELTA_400_UNION_{params.sr_folio}")
db.drop_delta(f"DELTA_500_MARCA_{params.sr_folio}")
db.drop_delta(f"DELTA_600_CARGA_{params.sr_folio}")
db.drop_delta(f"DELTA_700_BUC_{params.sr_folio}")
db.drop_delta(f"DELTA_700_VAL_IDENT_{params.sr_folio}")
db.drop_delta(f"DELTA_700_VIV_DUP_{params.sr_folio}")
db.drop_delta(f"DELTA_700_VIV_DUP_{params.sr_folio}")
db.drop_delta(f"DELTA_800_TRAMITE_{params.sr_folio}")
db.drop_delta(f"DELTA_BUC_DATOS_{params.sr_folio}")
db.drop_delta(f"DELTA_CARGA_{params.sr_folio}")
db.drop_delta(f"DELTA_DERECHA_{params.sr_folio}")
db.drop_delta(f"DELTA_DUPLICADOS_{params.sr_folio}")
db.drop_delta(f"DELTA_ENCONTRADOS_{params.sr_folio}")
db.drop_delta(f"DELTA_FECHA_{params.sr_folio}")
db.drop_delta(f"DELTA_IZQUIERDA_{params.sr_folio}")
db.drop_delta(f"DELTA_JOIN_300_DER_IZQ_{params.sr_folio}")
db.drop_delta(f"DELTA_NCI_{params.sr_folio}")
db.drop_delta(f"DELTA_NO_ENCONTRADOS_{params.sr_folio}")
db.drop_delta(f"DELTA_NO_VIGENTES_{params.sr_folio}")
db.drop_delta(f"DELTA_VARIASCTAS_{params.sr_folio}")
db.drop_delta(f"DELTA_VIGENTES_{params.sr_folio}")
db.drop_delta(f"DELTA_VIVIENDA_{params.sr_folio}")

#FOVISSSTE
db.drop_delta(f"DELTA_200_TRP_{params.sr_folio}")
db.drop_delta(f"DELTA_300_TRP_{params.sr_folio}")
db.drop_delta(f"DELTA_400_ENCONTRADOS_{params.sr_folio}")
db.drop_delta(f"DELTA_700_BUC2_{params.sr_folio}")
db.drop_delta(f"DELTA_700_NSS_{params.sr_folio}")
db.drop_delta(f"DELTA_700_SALIDA_{params.sr_folio}")
db.drop_delta(f"DELTA_700_VAL_IDENT2_{params.sr_folio}")
db.drop_delta(f"DELTA_701_ENCONTRADOS_{params.sr_folio}")
db.drop_delta(f"DELTA_CURP_{params.sr_folio}")
db.drop_delta(f"DELTA_ENCONTRADOS_NSS_{params.sr_folio}")

# %%
CleanUpManager.cleanup_notebook(locals())
