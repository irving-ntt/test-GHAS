# %%
# %run "./startup"

# %%
params = WidgetParams({
    "sr_folio": str,    
    "sr_tipo_arch": str,
    "sr_id_archivo": str,
    "sr_mot_rechazo": str,
    "sr_codigo_error": str,
    "sr_subproceso": str,
    "sr_nombrearch" : str
})
# Validar widgets
#params.validate()

# %%
if params.sr_subproceso == '354' :
    stage = "NB_PATRIF_INCO_0010_SDM_COMPARA_ARCH"
elif params.sr_subproceso == '368': 
    stage = "NB_PATRIF_INCO_RECH_0020_TI_368"
elif params.sr_subproceso == '364' :
    stage = "NB_PATRIF_INCO_RECH_0020_TI_364"
elif params.sr_subproceso == '365' :
    stage = "NB_PATRIF_INCO_RECH_0020_TI_365"        
elif params.sr_subproceso == '363' :
    stage = "NB_PATRIF_INCO_RECH_0030_TI_FOV"




dbutils.jobs.taskValues.set(key = "sr_folio", value = params.sr_folio)
dbutils.jobs.taskValues.set(key = "sr_tipo_arch", value = params.sr_tipo_arch)
dbutils.jobs.taskValues.set(key = "sr_id_archivo", value = params.sr_id_archivo)
dbutils.jobs.taskValues.set(key = "sr_mot_rechazo", value = params.sr_mot_rechazo)
dbutils.jobs.taskValues.set(key = "sr_codigo_error", value = params.sr_codigo_error)
dbutils.jobs.taskValues.set(key = "sr_subproceso", value = params.sr_subproceso)
dbutils.jobs.taskValues.set(key = "sr_nombrearch", value = params.sr_nombrearch)
dbutils.jobs.taskValues.set(key = "sr_stage", value = stage)
