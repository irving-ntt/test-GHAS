# %%
# %run "./startup"

# %%
params = WidgetParams({
    "sr_folio": str,   
    "sr_subproceso": str,
    "ind_vigencia": str,
    "config_indi": str,
    "sr_reproceso": str
})
# Validar widgets
#params.validate()

# %%
if params.sr_subproceso == '354' :
    stage = "JP_PATRIF_AIN_0100_ACT_IND_MARCA"
elif params.sr_subproceso == '368' or params.sr_subproceso == '364' or params.sr_subproceso == '365' : 
    stage = "JP_PATRIF_AIN_0100_ACT_IND_TRANF_INFO"
elif params.sr_subproceso == '363' :
    stage = "JP_PATRIF_AIN_0100_ACT_IND_TRANF_FOVI"     
elif params.sr_subproceso == '3286' :
    stage = "JP_PATRIF_AIN_0050_ACT_IND_TRP"
elif params.sr_subproceso == '3283' :
    stage = "Desmarca_Fovissste"    
elif params.sr_subproceso == '363' :
    stage = "Transferencias_Fovissste"        



dbutils.jobs.taskValues.set(key = "sr_stage", value = stage)
dbutils.jobs.taskValues.set(key = "sr_folio", value = params.sr_folio)
dbutils.jobs.taskValues.set(key = "sr_subproceso", value = params.sr_subproceso)
dbutils.jobs.taskValues.set(key = "ind_vigencia", value = params.ind_vigencia)
dbutils.jobs.taskValues.set(key = "config_indi", value = params.config_indi)
dbutils.jobs.taskValues.set(key = "sr_reproceso", value = params.sr_reproceso)
