# %%
# %run "./startup"

# %%
params = WidgetParams({
    "sr_folio": str,
    "sr_proceso": str,
    "sr_reproceso": str,
    "sr_subetapa": str,     
    "sr_subproceso": str,
    "sr_etapa": str,
    "sr_instancia_proceso": str,
    "sr_usuario": str,
    "sr_id_snapshot": str,
})
# Validar widgets
#params.validate()

# %%
Notify.send_notification("INFO", params)
