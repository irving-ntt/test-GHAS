# %%
# %sql
/*
NoteBook que simula el Job JP_PATRIF_GAR_0400_ARC_ACEP_LIN2 Que Genera el Detalle de archivos de Aceptacion del 
SUBPROCESO 354
*/

# %%
# %run "./startup"

# %%
params = WidgetParams(
    {
        "sr_proceso": str,
        "sr_subproceso": str,
        "sr_subetapa": str,
        "sr_folio": str,
        "sr_instancia_proceso": str,
        "sr_usuario": str,
        "sr_etapa": str,
        "sr_id_snapshot": str,
        "sr_id_archivo": str,
        "sr_fec_arc": str,
        "sr_paso": str,
        "sr_id_archivo_06": str,
        "sr_id_archivo_09": str
    }
)
params.validate()
conf = ConfManager()
query = QueryManager()
db = DBXConnectionManager()
queries_df = query.get_sql_list()
# filtar solo los registros donde la columan 'Archivo SQL' comiencen por el nombre del notebook
display(queries_df.filter(col("Archivo SQL").startswith("GAR")))

# %%
from datetime import datetime
import pytz

# Define the timezone for Mexico
mexico_tz = pytz.timezone("America/Mexico_City")

# Genera la fecha actual en el formato YYYYMMDD
fecha_actual = datetime.now(mexico_tz).strftime("%d-%m-%Y")

# %%
statement_001 = query.get_statement(
"GAR_0700_ARC_REC_LIN2_DETALLE.sql",
SR_FOLIO = params.sr_folio,
SR_SUBPROCESO = params.sr_subproceso,
SR_SYSDATE=fecha_actual
)

# %%
if conf.debug:
    df = db.read_data("default", statement_001)  # Ensure 'statement_001' has balanced parentheses and correct syntax.
if conf.debug:
    display(df)
    display(str(df.count()) + " Registros Totales")

# %%
temp_delta = 'DELTA_0700_ARC_REC_LIN2_DET' + '_' + params.sr_folio
db.write_delta(temp_delta, db.read_data("default", statement_001), "overwrite")
if conf.debug:
    display(db.read_delta(temp_delta))

# %%
CleanUpManager.cleanup_notebook(locals())
